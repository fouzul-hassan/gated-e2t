# %%
test v1 = ("/fouzul-hassan3-iit-sri-lanka/glim/runs/p67g6dls")

# %%
v1 noise = fouzul-hassan3-iit-sri-lanka/glim/runs/5s1jhf7s/

# %%
test v2 = ("/fouzul-hassan3-iit-sri-lanka/glim/runs/fb7mbm93")

# %%
v2 noise = /fouzul-hassan3-iit-sri-lanka/glim/runs/3j9vpjxh

# %%
# !python fetch_results.py --run "/fouzul-hassan3-iit-sri-lanka/glim/runs/p67g6dls" --run "fouzul-hassan3-iit-sri-lanka/glim/runs/5s1jhf7s" --run "/fouzul-hassan3-iit-sri-lanka/glim/runs/fb7mbm93" --run "/fouzul-hassan3-iit-sri-lanka/glim/runs/3j9vpjxh" --names "V1" "V1-N" "V2" "V2-N" --csv results.csv
# Out:
#   Fetching: /fouzul-hassan3-iit-sri-lanka/glim/runs/p67g6dls  (V1)
#   Fetching: fouzul-hassan3-iit-sri-lanka/glim/runs/5s1jhf7s  (V1-N)
#   Fetching: /fouzul-hassan3-iit-sri-lanka/glim/runs/fb7mbm93  (V2)
#   Fetching: /fouzul-hassan3-iit-sri-lanka/glim/runs/3j9vpjxh  (V2-N)
#
# ...
#   W&B Test Results
# ...
#
# -- Generation --
#        BLEU-1  BLEU-2  ROUGE-1 RAW
# Model
# V1     0.2068  0.0532       0.1132
# V1-N   0.0002  0.0000       0.0001
# V2     0.2034  0.0538       0.1123
# V2-N   0.0003  0.0000       0.0000
#
# -- Retrieval --
#        ACC-1 Retrieval  ACC-5 Retrieval
# Model
# V1              0.0720           0.3114
# V1-N            0.0417           0.2083
# V2              0.0734           0.2669
# V2-N            0.0417           0.2083
#
# -- Classification --
#        ACC-1 Relation  ACC-3 Relation  ACC Corpus
# Model
# V1             0.1367          0.3663      0.4121
# V1-N           0.0714          0.4827      0.1889
# V2             0.1531          0.3480      0.5711
# ...
