# %%
# %pwd
# Out:
# 'c:\\MSc Files\\MSc Project\\E2T-w-VJEPA\\gated-glim\\GLIM'

# %%
# %cd ..
# Out:
# c:\MSc Files\MSc Project\E2T-w-VJEPA\gated-glim\GLIM

# %%
from Dataset.zuco_dataset import load_zuco

# Load the dataset (adjust path to your data location)
data = load_zuco('./data/tmp/zuco_eeg_128ch_1280len.df')

print("All train shape:", data['All_train_data'].shape)
print("Test shape:", data['test_data'].shape)
print("Channels:", data['num_channels'], "Length:", data['max_len'])
print("Num classes (subjects):", data['All_train_label'].max() + 1)
