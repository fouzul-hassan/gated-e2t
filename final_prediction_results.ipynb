# %%
# !python predict.py --checkpoint runs/v1/epoch=199-step=397600.ckpt --task all --use_llm
# Out:
# Loading model from runs/v1/epoch=199-step=397600.ckpt...
# config.json: 100%|█████████████████████████████| 662/662 [00:00<00:00, 4.44MB/s]
# tokenizer_config.json: 2.54kB [00:00, 14.4MB/s]
# spiece.model: 100%|██████████████████████████| 792k/792k [00:00<00:00, 1.93MB/s]
# tokenizer.json: 2.42MB [00:00, 22.3MB/s]
# special_tokens_map.json: 2.20kB [00:00, 44.3kB/s]
# model.safetensors: 100%|████████████████████| 3.13G/3.13G [00:06<00:00, 474MB/s]
# Loading weights: 100%|██████████████████████| 558/558 [00:00<00:00, 4788.31it/s]
# T5ForConditionalGeneration LOAD REPORT from: google/flan-t5-large
# Key                         | Status  |
# ----------------------------+---------+-
# encoder.embed_tokens.weight | MISSING |
# decoder.embed_tokens.weight | MISSING |
#
# Notes:
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# generation_config.json: 100%|██████████████████| 147/147 [00:00<00:00, 1.39MB/s]
# ...

# %%
# !python predict.py --checkpoint runs/v2/epoch=199-step=397600.ckpt --task all --use_llm
# Out:
# Loading model from runs/v2/epoch=199-step=397600.ckpt...
# config.json: 1.40kB [00:00, 5.67MB/s]
# tokenizer_config.json: 2.54kB [00:00, 61.0kB/s]
# spiece.model: 100%|██████████████████████████| 792k/792k [00:00<00:00, 1.29MB/s]
# tokenizer.json: 2.42MB [00:00, 35.2MB/s]
# special_tokens_map.json: 2.20kB [00:00, 13.5MB/s]
# model.safetensors: 100%|██████████████████████| 308M/308M [00:01<00:00, 170MB/s]
# Loading weights: 100%|██████████████████████| 190/190 [00:00<00:00, 4980.99it/s]
# T5ForConditionalGeneration LOAD REPORT from: google/flan-t5-small
# Key                         | Status  |
# ----------------------------+---------+-
# encoder.embed_tokens.weight | MISSING |
# decoder.embed_tokens.weight | MISSING |
#
# Notes:
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# generation_config.json: 100%|██████████████████| 147/147 [00:00<00:00, 1.78MB/s]
# ...

# %%
# !python predict.py --checkpoint runs/v1/epoch=199-step=397600.ckpt --task relation --use_llm
# Out:
# Loading model from runs/v1/epoch=199-step=397600.ckpt...
# Loading weights: 100%|███████████████████████| 558/558 [00:03<00:00, 146.84it/s]
# T5ForConditionalGeneration LOAD REPORT from: google/flan-t5-large
# Key                         | Status  |
# ----------------------------+---------+-
# decoder.embed_tokens.weight | MISSING |
# encoder.embed_tokens.weight | MISSING |
#
# Notes:
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Loading data from ./data/tmp/zuco_eeg_label_8variants.df...
# [Rank 0][GLIMDataModule] running `setup()`...
# [Rank 0][GLIMDataModule] running `setup()`...Done! 😋😋😋
# Loading LLM: meta-llama/Meta-Llama-3.1-8B-Instruct...
# `torch_dtype` is deprecated! Use `dtype` instead!
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|███████████████████████| 291/291 [00:02<00:00, 114.51it/s]
#
# ...
# RELATION CLASSIFICATION
# ...
#
# ...

# %%
# !python predict.py --checkpoint runs/v2/epoch=199-step=397600.ckpt --task relation --use_llm
# Out:
# Loading model from runs/v2/epoch=199-step=397600.ckpt...
# Loading weights: 100%|██████████████████████| 190/190 [00:00<00:00, 6491.09it/s]
# T5ForConditionalGeneration LOAD REPORT from: google/flan-t5-small
# Key                         | Status  |
# ----------------------------+---------+-
# decoder.embed_tokens.weight | MISSING |
# encoder.embed_tokens.weight | MISSING |
#
# Notes:
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Loading data from ./data/tmp/zuco_eeg_label_8variants.df...
# [Rank 0][GLIMDataModule] running `setup()`...
# [Rank 0][GLIMDataModule] running `setup()`...Done! 😋😋😋
# Loading LLM: meta-llama/Meta-Llama-3.1-8B-Instruct...
# `torch_dtype` is deprecated! Use `dtype` instead!
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|███████████████████████| 291/291 [00:02<00:00, 131.38it/s]
#
# ...
# RELATION CLASSIFICATION
# ...
#
# ...

# %%
print('hello')
# Out:
# hello
